# %% [markdown]
# # Identificação de Alzaimer em imagens RX
#
# * Mohammad Reza Tabrizi

# %%
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

with plt.style.context('Solarize_Light2'):
    plt.plot((history_model_CNN_API_2.history['accuracy']),label='API2', linestyle='-.', color='b')
    plt.plot((history5.history['accuracy']),label='CNN3', color='k')
    plt.plot((history2.history['accuracy']),label='CNN2_DrupOut_0.5', linestyle=':', color='y')
    plt.plot((history1.history['accuracy']),label='CNN1', linestyle='--', color='r')
    plt.plot((best_history.history['accuracy']),label='best_model', color='g')

    plt.title('ACCURACY CNN - Line')
    plt.xlabel('# epochs', fontsize=14)
    plt.ylabel('accuracy', fontsize=14)
    ax = plt.subplot(111)
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    #plt.legend(loc='best')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   del sys.path[0]

# %%
CNN3=((history5.history['val_accuracy'])[-1])*100

CNN2=((history2.history['accuracy'])[-1])*100
CNN1=((history1.history['accuracy'])[-1])*100
API2=((history_model_CNN_API_2.history['accuracy'])[-1])*100
Optimal=((best_history.history['accuracy'])[-1])*100
plt.figure(figsize=(20,5))
ind = np.arange(5)
width = 0.2

labels = ['CNN1', 'CNN2_DrupOut_0.5','CNN3','API2','Beast Model']
bar_08 = plt.bar(ind, [CNN1,CNN2,CNN3,API2,Optimal],width, color='y', label='accuracy')
location = ind+width/2
labels=labels
plt.xticks(location, labels)
axes = plt.gca()
axes.set_ylim([0,110])
plt.legend(loc='best')
